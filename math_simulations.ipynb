# %% [markdown]
# # Clinical Trial Patient Demand Calculator
#
# Interact with the Streamlit dashboard directly inside this notebook. Adjust trial and dosing parameters to see total patient demand update instantly.

# %%
# Install required packages
# !pip install -r requirements.txt
# Out:
# zsh:1: /Users/jacksonmckinley/dad_math/.venv/bin/pip: bad interpreter: /Users/jacksonmckinley/dad_math/.venv2/bin/python: no such file or directory
# Requirement already satisfied: jupyter in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (1.1.1)
# Collecting streamlit (from -r requirements.txt (line 2))
#   Using cached streamlit-1.51.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting streamlit-jupyter (from -r requirements.txt (line 3))
#   Using cached streamlit_jupyter-0.3.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: notebook in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 1)) (7.2.2)
# Requirement already satisfied: jupyter-console in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 1)) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 1)) (7.16.4)
# Requirement already satisfied: ipykernel in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 1)) (6.29.5)
# Requirement already satisfied: ipywidgets in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 1)) (8.1.3)
# Requirement already satisfied: jupyterlab in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 1)) (4.2.5)
# Collecting altair!=5.4.0,!=5.4.1,<6,>=4.0 (from streamlit->-r requirements.txt (line 2))
#   Using cached altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit->-r requirements.txt (line 2))
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<7,>=4.0 (from streamlit->-r requirements.txt (line 2))
#   Using cached cachetools-6.2.1-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: click<9,>=7.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 2)) (8.3.0)
# Requirement already satisfied: numpy<3,>=1.23 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: packaging<26,>=20 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 2)) (24.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 2)) (10.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 2)) (5.29.3)
# Collecting pyarrow<22,>=7.0 (from streamlit->-r requirements.txt (line 2))
#   Using cached pyarrow-21.0.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Requirement already satisfied: requests<3,>=2.27 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 2)) (9.0.0)
# Collecting toml<2,>=0.10.1 (from streamlit->-r requirements.txt (line 2))
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 2)) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit->-r requirements.txt (line 2))
#   Using cached gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->-r requirements.txt (line 2))
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 2)) (6.4.1)
# Requirement already satisfied: jinja2 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 2)) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 2)) (4.23.0)
# Collecting narwhals>=1.14.2 (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 2))
#   Using cached narwhals-2.10.1-py3-none-any.whl.metadata (11 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 2))
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 2))
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 2)) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 2)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 2)) (2024.8.30)
# Collecting fastcore (from streamlit-jupyter->-r requirements.txt (line 3))
#   Using cached fastcore-1.8.14-py3-none-any.whl.metadata (3.7 kB)
# Collecting stqdm (from streamlit-jupyter->-r requirements.txt (line 3))
#   Using cached stqdm-0.0.5-py3-none-any.whl.metadata (3.0 kB)
# Collecting tabulate (from streamlit-jupyter->-r requirements.txt (line 3))
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: tqdm in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from streamlit-jupyter->-r requirements.txt (line 3)) (4.66.2)
# Requirement already satisfied: comm>=0.1.3 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (8.26.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (3.0.11)
# Requirement already satisfied: decorator in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->jupyter->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->jupyter->-r requirements.txt (line 1)) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->jupyter->-r requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->jupyter->-r requirements.txt (line 1)) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->jupyter->-r requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: stack-data in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->jupyter->-r requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: exceptiongroup in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->jupyter->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->jupyter->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: wcwidth in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->jupyter->-r requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->jupyter->-r requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 2)) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 2)) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 2)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 2)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 2)) (0.20.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->jupyter->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: appnope in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.8.5)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.7.2)
# Requirement already satisfied: nest-asyncio in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: psutil in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (26.1.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 1)) (4.2.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (0.27.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (69.5.1)
# Requirement already satisfied: tomli>=1.2.2 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: anyio>=3.1.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.9.25)
# Requirement already satisfied: sniffio>=1.1 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: fqdn in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.4)
# Requirement already satisfied: uri-template in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (24.8.0)
# Requirement already satisfied: beautifulsoup4 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: defusedxml in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: webencodings in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.22)
# Requirement already satisfied: soupsieve>1.2 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 1)) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.9.0.20240316)
# Requirement already satisfied: executing>=1.2.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->jupyter->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->jupyter->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/jacksonmckinley/miniforge3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->jupyter->-r requirements.txt (line 1)) (0.2.3)
# Using cached streamlit-1.51.0-py3-none-any.whl (10.2 MB)
# Using cached altair-5.5.0-py3-none-any.whl (731 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached cachetools-6.2.1-py3-none-any.whl (11 kB)
# Using cached gitpython-3.1.45-py3-none-any.whl (208 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached pyarrow-21.0.0-cp310-cp310-macosx_12_0_arm64.whl (31.2 MB)
# Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached streamlit_jupyter-0.3.1-py3-none-any.whl (13 kB)
# Using cached narwhals-2.10.1-py3-none-any.whl (419 kB)
# Using cached fastcore-1.8.14-py3-none-any.whl (86 kB)
# Using cached stqdm-0.0.5-py3-none-any.whl (11 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: toml, tabulate, smmap, pyarrow, narwhals, fastcore, cachetools, blinker, pydeck, gitdb, gitpython, altair, streamlit, stqdm, streamlit-jupyter
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [streamlit-jupyter]streamlit]
# Successfully installed altair-5.5.0 blinker-1.9.0 cachetools-6.2.1 fastcore-1.8.14 gitdb-4.0.12 gitpython-3.1.45 narwhals-2.10.1 pyarrow-21.0.0 pydeck-0.9.1 smmap-5.0.2 stqdm-0.0.5 streamlit-1.51.0 streamlit-jupyter-0.3.1 tabulate-0.9.0 toml-0.10.2

# %%
# Enable Streamlit to render inline within Jupyter
from streamlit_jupyter import StreamlitPatcher

patcher = StreamlitPatcher()
patcher.jupyter()

# %%
# Define the demand calculator app
from dataclasses import dataclass
from typing import Dict

import streamlit as st

try:
    from streamlit.errors import StreamlitAPIException
except ImportError:  # pragma: no cover
    StreamlitAPIException = Exception  # type: ignore


@dataclass
class DosingParams:
    patients: int
    products: int
    product_amount: float
    admin_points: int
    days: int
    buffer_pct: int


def inject_custom_css() -> None:
    st.markdown(
        """
        <style>
        :root {
            --primary-color: #0b5ea8;
            --accent-color: #2f9be0;
            --bg-gradient-top: #f6fbff;
            --bg-gradient-bottom: #eef5fb;
            --text-color: #0b2948;
            --muted-color: #5b6b7f;
        }

        .stApp {
            background: linear-gradient(180deg, var(--bg-gradient-top), var(--bg-gradient-bottom));
        }

        .main .block-container {
            padding-top: 2.5rem;
            padding-bottom: 3rem;
            max-width: 1100px;
        }

        .trial-expander {
            border-radius: 18px !important;
            border: 1px solid rgba(11, 94, 168, 0.15) !important;
            background-color: rgba(255, 255, 255, 0.88) !important;
            box-shadow: 0 6px 24px rgba(11, 41, 72, 0.08);
            padding: 0.4rem 0.2rem 1.2rem 0.2rem;
        }

        .group-card {
            border-radius: 16px;
            padding: 1.1rem 1.3rem;
            margin-bottom: 1.1rem;
            background-color: rgba(255, 255, 255, 0.92);
            border: 1px solid rgba(47, 155, 224, 0.24);
            box-shadow: 0 4px 16px rgba(11, 94, 168, 0.08);
        }

        .result-card {
            border-radius: 24px;
            padding: 2.4rem 2.6rem;
            background: linear-gradient(150deg, rgba(47, 155, 224, 0.18), rgba(11, 94, 168, 0.32));
            box-shadow: 0 18px 45px rgba(11, 41, 72, 0.18);
            text-align: center;
        }

        .result-card h2 {
            color: var(--text-color);
            margin-bottom: 0.4rem;
            font-weight: 600;
        }

        .result-card h1 {
            color: #05529b;
            font-size: clamp(2.8rem, 6vw, 3.6rem);
            font-weight: 700;
            margin-bottom: 0.3rem;
        }

        .result-card p {
            color: var(--muted-color);
            margin: 0;
        }

        .stNumberInput > label {
            font-weight: 600;
            color: var(--text-color);
        }

        .help-tooltip {
            color: var(--muted-color) !important;
        }

        .stExpander .streamlit-expanderHeader {
            font-weight: 600;
            color: var(--text-color);
            font-size: 1.02rem;
        }

        .stMetric-label {
            color: var(--muted-color) !important;
        }

        .stMetric-value {
            color: var(--text-color) !important;
        }
        </style>
        """
    , unsafe_allow_html=True)


def configure_page(*, embedded: bool = False) -> None:
    try:
        st.set_page_config(
            page_title="Clinical Trial Patient Demand Calculator",
            page_icon="",
            layout="centered",
            initial_sidebar_state="expanded",
        )
    except StreamlitAPIException:
        pass
    except RuntimeError:
        if not embedded:
            raise


def card_container():
    try:
        return st.container(border=True)
    except TypeError:
        return st.container()


def calculate_group_demand(params: DosingParams) -> float:
    base = (
        params.patients
        * params.products
        * params.product_amount
        * params.admin_points
        * params.days
    )
    return base * (1 + params.buffer_pct / 100.0)


def run_app(*, embedded: bool = False) -> None:
    configure_page(embedded=embedded)
    inject_custom_css()

    st.markdown(
        """
        <div style="text-align:center; margin-bottom: 1.6rem;">
            <h1 style="color:#0b2948;">Clinical Trial Patient Demand Calculator</h1>
            <p style="color:#5b6b7f; font-size:1.05rem;">
                Model patient-level dosing needs across trials with flexible treatment configurations.
            </p>
        </div>
        """
        , unsafe_allow_html=True
    )

    st.sidebar.markdown("## Planner Settings")
    num_trials = st.sidebar.number_input(
        "Number of Trials",
        min_value=1,
        max_value=25,
        value=1,
        step=1,
        help="How many clinical trials should be included in this demand model?",
    )

    st.sidebar.info(
        "Adjust baseline dosing for each trial and fine-tune group level assumptions for precision.",
    )

    st.sidebar.markdown(
        """
        **Reminder**: Total demand reflects every administration event across trials and treatment groups.
        """
    )

    total_demand = 0.0
    trial_totals: Dict[str, float] = {}

    for trial_index in range(1, num_trials + 1):
        with st.expander(
            f"Trial {trial_index} configuration",
            expanded=(trial_index == 1),
        ):
            st.markdown("<div class='trial-expander'>", unsafe_allow_html=True)

            details_cols = st.columns(2)
            num_groups = int(
                details_cols[0].number_input(
                    "Treatment Groups",
                    min_value=1,
                    max_value=12,
                    value=2,
                    step=1,
                    key=f"trial_{trial_index}_groups",
                    help="How many treatment arms or cohorts are in this trial?",
                )
            )
            products_per_trial = details_cols[1].number_input(
                "Products per Trial",
                min_value=1,
                max_value=10,
                value=1,
                step=1,
                key=f"trial_{trial_index}_products",
                help="Count formulations, strengths, or presentations required for this trial.",
            )

            dosing_defaults = st.columns(3)
            default_product_amount = dosing_defaults[0].number_input(
                "Product per Administration (mg)",
                min_value=0.0,
                value=50.0,
                step=5.0,
                format="%.2f",
                key=f"trial_{trial_index}_product_amount",
                help="Baseline dose per administration event. Adjust per group when needed.",
            )
            default_admin_points = dosing_defaults[1].number_input(
                "Administration Points / Day",
                min_value=1,
                max_value=24,
                value=1,
                step=1,
                key=f"trial_{trial_index}_admin_points",
                help="Number of dosing events each day (e.g., BID = 2).",
            )
            default_days = dosing_defaults[2].number_input(
                "Days of Administration",
                min_value=1,
                max_value=365,
                value=28,
                step=1,
                key=f"trial_{trial_index}_days",
                help="Planned duration of treatment for the trial.",
            )

            st.caption(
                "Tune individual treatment group inputs below to capture protocol nuances."
            )

            trial_total = 0.0
            for group_index in range(1, num_groups + 1):
                with card_container():
                    st.markdown(
                        "<div class='group-card'>",
                        unsafe_allow_html=True,
                    )
                    st.markdown(
                        f"<h4 style='margin-top:0;color:#0b2948;'>Treatment Group {group_index}</h4>",
                        unsafe_allow_html=True,
                    )

                    top_cols = st.columns(3)
                    patients = top_cols[0].number_input(
                        "Patients",
                        min_value=1,
                        max_value=1000,
                        value=50,
                        step=1,
                        key=f"trial_{trial_index}_group_{group_index}_patients",
                        help="Participants randomised or assigned to this treatment group.",
                    )
                    product_amount = top_cols[1].number_input(
                        "Product per Administration (mg)",
                        min_value=0.0,
                        value=default_product_amount,
                        step=5.0,
                        format="%.2f",
                        key=f"trial_{trial_index}_group_{group_index}_amount",
                        help="Dose per administration for this group.",
                    )
                    admin_points = top_cols[2].number_input(
                        "Administration Points / Day",
                        min_value=1,
                        max_value=24,
                        value=int(default_admin_points),
                        step=1,
                        key=f"trial_{trial_index}_group_{group_index}_points",
                        help="Daily dosing frequency for this group.",
                    )

                    bottom_cols = st.columns(3)
                    days = bottom_cols[0].number_input(
                        "Days of Administration",
                        min_value=1,
                        max_value=365,
                        value=int(default_days),
                        step=1,
                        key=f"trial_{trial_index}_group_{group_index}_days",
                        help="Number of treatment days for this group.",
                    )
                    products_multiplier = bottom_cols[1].number_input(
                        "Products per Trial",
                        min_value=1,
                        max_value=10,
                        value=int(products_per_trial),
                        step=1,
                        key=f"trial_{trial_index}_group_{group_index}_products",
                        help="Use when a group requires multiple product presentations.",
                    )
                    buffer_pct = bottom_cols[2].number_input(
                        "Contingency Buffer (%)",
                        min_value=0,
                        max_value=100,
                        value=0,
                        step=5,
                        key=f"trial_{trial_index}_group_{group_index}_buffer",
                        help="Optional overage to cover wastage or resupply (applies to this group only).",
                    )

                    group_params = DosingParams(
                        patients=int(patients),
                        products=int(products_multiplier),
                        product_amount=float(product_amount),
                        admin_points=int(admin_points),
                        days=int(days),
                        buffer_pct=int(buffer_pct),
                    )
                    group_demand = calculate_group_demand(group_params)

                    trial_total += group_demand
                    total_demand += group_demand

                    st.markdown(
                        f"<p style='color:#5b6b7f;margin:0.8rem 0 0;'>Group demand contribution: <strong>{group_demand:,.0f}</strong></p>",
                        unsafe_allow_html=True,
                    )
                    st.markdown("</div>", unsafe_allow_html=True)

            st.markdown("</div>", unsafe_allow_html=True)
            trial_totals[f"Trial {trial_index}"] = trial_total

    st.divider()

    rounded_demand = int(round(total_demand))
    with card_container():
        st.markdown(
            """
            <div class='result-card'>
                <h2>&#128138; Total Patient Demand</h2>
                <h1>{:,}</h1>
                <p>Sum of all product administrations across trials, groups, and buffers.</p>
            </div>
            """.format(rounded_demand),
            unsafe_allow_html=True,
        )

    if trial_totals:
        items = list(trial_totals.items())
        for idx in range(0, len(items), 3):
            row = items[idx : idx + 3]
            metric_cols = st.columns(len(row))
            for col, (label, value) in zip(metric_cols, row):
                col.metric(label=label, value=f"{int(round(value)):,}")

    st.caption("Adjust protocol settings to refresh the demand estimate instantly.")


print("Demand calculator ready. Call run_app(embedded=True) to display it.")
# Out:
# Demand calculator ready. Call run_app(embedded=True) to display it.

# %%
# Display the app
run_app(embedded=True)
# Out:
# 2025-11-02 22:59:06.520 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#         <style>
#         :root {
#             --primary-color: #0b5ea8;
#             --accent-color: #2f9be0;
#             --bg-gradient-top: #f6fbff;
#             --bg-gradient-bottom: #eef5fb;
#             --text-color: #0b2948;
#             --muted-color: #5b6b7f;
#         }
#
#         .stApp {
#             background: linear-gradient(180deg, var(--bg-gradient-top), var(--bg-gradient-bottom));
#         }
#
#         .main .block-container {
#             padding-top: 2.5rem;
#             padding-bottom: 3rem;
#             max-width: 1100px;
#         }
#
#         .trial-expander {
#             border-radius: 18px !important;
#             border: 1px solid rgba(11, 94, 168, 0.15) !important;
#             background-color: rgba(255, 255, 255, 0.88) !important;
#             box-shadow: 0 6px 24px rgba(11, 41, 72, 0.08);
#             padding: 0.4rem 0.2rem 1.2rem 0.2rem;
#         }
#
#         .group-card {
#             border-radius: 16px;
#             padding: 1.1rem 1.3rem;
#             margin-bottom: 1.1rem;
#             background-color: rgba(255, 255, 255, 0.92);
#             border: 1px solid rgba(47, 155, 224, 0.24);
#             box-shadow: 0 4px 16px rgba(11, 94, 168, 0.08);
#         }
#
#         .result-card {
#             border-radius: 24px;
#             padding: 2.4rem 2.6rem;
#             background: linear-gradient(150deg, rgba(47, 155, 224, 0.18), rgba(11, 94, 168, 0.32));
#             box-shadow: 0 18px 45px rgba(11, 41, 72, 0.18);
#             text-align: center;
#         }
#
#         .result-card h2 {
#             color: var(--text-color);
#             margin-bottom: 0.4rem;
#             font-weight: 600;
#         }
#
#         .result-card h1 {
#             color: #05529b;
#             font-size: clamp(2.8rem, 6vw, 3.6rem);
#             font-weight: 700;
#             margin-bottom: 0.3rem;
#         }
#
#         .result-card p {
#             color: var(--muted-color);
#             margin: 0;
#         }
#
#         .stNumberInput > label {
#             font-weight: 600;
#             color: var(--text-color);
#         }
#
#         .help-tooltip {
#             color: var(--muted-color) !important;
#         }
#
#         .stExpander .streamlit-expanderHeader {
#             font-weight: 600;
#             color: var(--text-color);
#             font-size: 1.02rem;
#         }
#
#         .stMetric-label {
#             color: var(--muted-color) !important;
#         }
#
#         .stMetric-value {
#             color: var(--text-color) !important;
#         }
#         </style>
#         <div style="text-align:center; margin-bottom: 1.6rem;">
#             <h1 style="color:#0b2948;">Clinical Trial Patient Demand Calculator</h1>
#             <p style="color:#5b6b7f; font-size:1.05rem;">
#                 Model patient-level dosing needs across trials with flexible treatment configurations.
#             </p>
#         </div>
# 2025-11-02 22:59:06.527 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.616
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/jacksonmckinley/dad_math/.venv/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-11-02 22:59:06.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.618 Session state does not function when running a script without `streamlit run`
# 2025-11-02 22:59:06.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.616
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/jacksonmckinley/dad_math/.venv/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-11-02 22:59:06.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.618 Session state does not function when running a script without `streamlit run`
# 2025-11-02 22:59:06.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# >**expander starts**: Trial 1 configuration
# <div class='trial-expander'>
# 2025-11-02 22:59:06.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# > Tune individual treatment group inputs below to capture protocol nuances.
# 2025-11-02 22:59:06.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# <div class='group-card'>
# <h4 style='margin-top:0;color:#0b2948;'>Treatment Group 1</h4>
# 2025-11-02 22:59:06.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# <p style='color:#5b6b7f;margin:0.8rem 0 0;'>Group demand contribution: <strong>70,000</strong></p>
# </div>
# 2025-11-02 22:59:06.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# <div class='group-card'>
# <h4 style='margin-top:0;color:#0b2948;'>Treatment Group 2</h4>
# 2025-11-02 22:59:06.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.685 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.686 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.685 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.686 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# <p style='color:#5b6b7f;margin:0.8rem 0 0;'>Group demand contribution: <strong>70,000</strong></p>
# </div>
# </div>
# >**expander ends**
# 2025-11-02 22:59:06.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#             <div class='result-card'>
#                 <h2>&#128138; Total Patient Demand</h2>
#                 <h1>140,000</h1>
#                 <p>Sum of all product administrations across trials, groups, and buffers.</p>
#             </div>
# 2025-11-02 22:59:06.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-02 22:59:06.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# > Adjust protocol settings to refresh the demand estimate instantly.

# %% [markdown]
# ---
# If the widgets fail to render, ensure the `streamlit-jupyter` package is installed and rerun the Streamlit patch cell above.
